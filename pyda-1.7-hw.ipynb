# %%
import pandas as pd

# %%
movies = pd.read_csv('movies.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings = pd.read_csv('ratings.csv')
ratings.head()
joined = ratings.merge(movies, on='movieId', how='left')
joined.head()
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
# Задание 1
# Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
# - оценка 2 и меньше - низкий рейтинг
# - оценка 4 и меньше - средний рейтинг
# - оценка 4.5 и 5 - высокий рейтинг

# Результат классификации запишите в столбец class

def class_rating(item):
    if item <= 2.0:
        return 'low'
    elif item > 2.0 and item <= 4.0:
        return 'middle'
    else:
        return 'hight'

# %%
grouped = joined.groupby('movieId').mean()

# %%
grouped['class'] = grouped['rating'].apply(class_rating)
grouped.head(30)
# Out:
#              userId    rating     timestamp   class
# movieId
# 1        232.218182  3.954545  1.113378e+09  middle
# 2        242.269231  3.365385  1.110902e+09  middle
# 3        204.175000  3.312500  9.853303e+08  middle
# 4        156.500000  2.500000  8.420487e+08  middle
# 5        232.605263  3.276316  9.417387e+08  middle
# 6        237.556962  3.924051  1.063230e+09  middle
# 7        187.600000  3.262500  9.441748e+08  middle
# 8        223.571429  2.857143  9.414515e+08  middle
# 9        336.857143  3.107143  9.109635e+08  middle
# 10       244.267327  3.485149  1.025500e+09  middle
# 11       218.961538  3.826923  9.675445e+08  middle
# 12       254.800000  2.633333  9.921726e+08  middle
# 13       160.833333  3.166667  1.041885e+09  middle
# 14       286.000000  3.846154  8.905629e+08  middle
# 15       180.857143  3.285714  8.879005e+08  middle
# 16       261.656716  3.985075  1.131672e+09  middle
# 17       230.686275  3.794118  9.888364e+08  middle
# 18       201.142857  3.714286  1.188348e+09  middle
# 19       224.619048  2.698413  1.118374e+09  middle
# 20       287.636364  2.818182  1.115569e+09  middle
# 21       232.902778  3.451389  9.611060e+08  middle
# 22       254.851852  3.148148  9.737916e+08  middle
# 23       202.916667  3.333333  1.006341e+09  middle
# 24       240.111111  3.222222  9.945495e+08  middle
# 25       235.619048  3.658730  9.969407e+08  middle
# 26       196.500000  3.650000  9.262193e+08  middle
# 27       325.142857  3.428571  1.016768e+09  middle
# 28       215.333333  4.333333  1.139226e+09   hight
# 29       252.862069  4.155172  1.119903e+09   hight
# 30       325.000000  4.000000  1.039400e+09  middle

# %%
# Используем файл keywords.csv.

# Необходимо написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определенному региону. Т. е. если поисковый запрос содержит название города региона, то в столбце ‘region’ пишется название этого региона. Если поисковый запрос не содержит названия города, то ставим ‘undefined’.

# Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:

# geo_data = {

# 'Центр': ['москва', 'тула', 'ярославль'],

# 'Северо-Запад': ['петербург', 'псков', 'мурманск'],

# 'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
# }

# Результат классификации запишите в отдельный столбец region.

# %%
kw = pd.read_csv('keywords.csv')

# %%
kw.head(30)
# Out:
#                           keyword       shows
# 0                              вк  64292779.0
# 1                   одноклассники  63810309.0
# 2                           порно  41747114.0
# 3                            ютуб  39995567.0
# 4                       вконтакте  21014195.0
# 5      одноклассники моя страница  19976138.0
# 6                            майл  15144673.0
# 7                           авито  14786593.0
# 8                      переводчик  14453469.0
# 9                          яндекс  13344734.0
# 10                сбербанк онлайн  10725673.0
# 11                           mail   7687204.0
# 12                           игры   6075762.0
# 13                        youtube   5729958.0
# 14         вконтакте моя страница   5971451.0
# 15                           секс   5431732.0
# 16                           гугл   5175471.0
# 17                             dr   4880955.0
# 18                    алиэкспресс   4879645.0
# 19                        рамблер   4540421.0
# 20                    фильмы 2016   4486635.0
# 21                         погода   4344510.0
# 22                             vk   4330448.0
# 23              ютуб видеохостинг   4215267.0
# 24                          дойки   4133424.0
# 25  одноклассники социальная сеть   4018230.0
# 26                       мультики   3866664.0
# 27                        контакт   3815111.0
# 28                        фейсбук   3669993.0
# 29                    порно видео   3858938.0

# %%
geo_data = {

'Центр': ['москва', 'тула', 'ярославль'],

'Северо-Запад': ['петербург', 'псков', 'мурманск'],

'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
}

# %%
for row in geo_data:
    print(geo_data[row])
# Out:
# ['москва', 'тула', 'ярославль']
# ['петербург', 'псков', 'мурманск']
# ['владивосток', 'сахалин', 'хабаровск']

# %%
b1 = [1,2,3,4,5,9,11,15]
b2 = [4,6,7,8]
len(set(b1).intersection(b2))
# Out:
# 1

# %%
def find_geo(keywords):
    rows = []
    for row in geo_data:
        if len(set(geo_data[row]).intersection(keywords.split(' '))) > 0:
            rows.append(row)
    if len(rows) > 0:
        return ' '.join(rows)
    return 'undefined'

# %%
kw['region'] = kw.keyword.apply(find_geo)

# %%
kw[kw.region != 'undefined'].head(20)
# Out:
#                                  keyword     shows          region
# 127                         авито москва  979292.0           Центр
# 370             авито ру санкт петербург  425134.0    Северо-Запад
# 849                      авито ярославль  209581.0           Центр
# 1063                 фарпост владивосток  176951.0  Дальний Восток
# 1236                банк санкт петербург  174375.0    Северо-Запад
# 1259                              москва  153050.0           Центр
# 1346                     санкт петербург  144232.0    Северо-Запад
# 1396                     гисметео москва  140279.0           Центр
# 1482                    госуслуги москва  133061.0           Центр
# 1579                          авито тула  126168.0           Центр
# 1682                       погода москва  151701.0           Центр
# 2153                         авито псков   98931.0    Северо-Запад
# 2175                      дром хабаровск   98361.0  Дальний Восток
# 2398                      авито мурманск   89787.0    Северо-Запад
# 2550  банк санкт петербург интернет банк   89123.0    Северо-Запад
# 2806            циан недвижимость москва   78729.0           Центр
# 2974             авто ру санкт петербург   74918.0    Северо-Запад
# 3206                    дром владивосток   73084.0  Дальний Восток
# 3275                  100 сп владивосток   76418.0  Дальний Восток
# 3687                     авито хабаровск   63736.0  Дальний Восток

# %%
# Задание 3
# Есть мнение, что “раньше снимали настоящее кино, не то что сейчас”.
# Ваша задача проверить это утверждение, используя файлы с рейтингами фильмов из материалов занятия.
# Т. е. проверить верно ли, что с ростом года выпуска фильма его средний рейтинг становится ниже.

# При этом мы не будем затрагивать субьективные факторы выставления этих рейтингов, 
# а пройдемся по следующему алгоритму:

# В переменную years запишите список из всех годов с 1950 по 2010.

# Напишите функцию production_year, которая каждой строке из названия фильма выставляет
# год выпуска. Не все названия фильмов содержат год выпуска в одинаковом формате,
# поэтому используйте следующий алгоритм:

# для каждой строки пройдите по всем годам списка years
# если номер года присутствует в названии фильма, то функция возвращает этот год как год выпуска
# если ни один из номеров года списка years не встретился в названии фильма, то возвращается 1900 год
# Запишите год выпуска фильма по алгоритму пункта 2 в новый столбец ‘year’

# Посчитайте средний рейтинг всех фильмов для каждого значения столбца ‘year’ 
# и отсортируйте результат по убыванию рейтинга

# %%
years = list(range(1950,2010))

# %%
def production_year(name):
    for year in years:
        if str(year) in name:
            return year
    return 1900

# %%
joined['year'] = joined.title.apply(production_year)
joined.head()
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1