# %%
from pyspark.sql import SparkSession

# %%
import pandas as pd

# %%
spark = SparkSession.builder.getOrCreate()

# %%
df = spark.read.csv('titanic.csv', header=True)

# %%
df.head()
# Out:
# Row(PassengerId='1', Survived='0', Pclass='3', Name='Braund, Mr. Owen Harris', Sex='male', Age='22.0', SibSp='1', Parch='0', Ticket='A/5 21171', Fare='7.25', Cabin=None, Embarked='S')

# %%
from pymongo import MongoClient

# %%
myclient = MongoClient("mongodb://localhost:27017/")

# %%
mydb = myclient["titanic"]

# %%
print(myclient.list_database_names())
# Out:
# ['admin', 'config', 'local', 'titanic']

# %%
mydb = df

# %%
mydb
# Out:
# DataFrame[PassengerId: string, Survived: string, Pclass: string, Name: string, Sex: string, Age: string, SibSp: string, Parch: string, Ticket: string, Fare: string, Cabin: string, Embarked: string]

# %%
mydb = myclient["titanic"]

# %%
print(myclient.list_database_names())
# Out:
# ['admin', 'config', 'local', 'titanic']

# %%
myclient["titanic"]
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'titanic')

# %%
print(myclient.list_database_names())
# Out:
# ['admin', 'config', 'local', 'titanic']

# %%
test_col = mydb["test"]
train_col = mydb["train"]

# %%
print(mydb.list_collection_names())
# Out:
# ['test', 'train']

# %%
test = spark.read.csv('test.csv', header=True)

# %%
train = spark.read.csv('train.csv', header=True)

# %%
import csv

# %%
import json

# %%
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4e1243bd22c6> in <module>
# ----> 1 test
#
# NameError: name 'test' is not defined

# %%
test
# Out:
# DataFrame[PassengerId: string, Pclass: string, Name: string, Sex: string, Age: string, SibSp: string, Parch: string, Ticket: string, Fare: string, Cabin: string, Embarked: string]

# %%
test.head()
# Out:
# Row(PassengerId='892', Pclass='3', Name='Kelly, Mr. James', Sex='male', Age='34.5', SibSp='0', Parch='0', Ticket='330911', Fare='7.8292', Cabin=None, Embarked='Q')

# %%
import sys, getopt

# %%
import csv

# %%
import json

# %%
import pandas

# %%
colnames = ['pclass', 'sex', 'Age', 'sibsp', 'parch', 'ticket', 'fare', 'cabin', 'embarked2']

# %%
colnames
# Out:
# ['pclass',
#  'sex',
#  'Age',
#  'sibsp',
#  'parch',
#  'ticket',
#  'fare',
#  'cabin',
#  'embarked2']

# %%
data = pandas.read_csv('test.csv', names=colnames)

# %%
names = data.sex.tolist()

# %%
names
# Out:
# ['male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'female',
#  'male',
#  'male',
#  'female',
#  'female',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'female',
#  'male',
#  'female',
#  'male',
#  'male',
#  'male',
#  'male',
#  'male',
# ...

# %%
data = pd.read_csv("test.csv")

# %%
data['Pclass'].values
# Out:
# array([3, 3, 2, 3, 3, 3, 3, 2, 3, 3, 3, 1, 1, 2, 1, 2, 2, 3, 3, 3, 1, 3,
#        1, 1, 1, 3, 1, 3, 1, 3, 2, 2, 3, 3, 1, 3, 3, 3, 3, 3, 3, 1, 3, 2,
#        1, 3, 1, 3, 1, 3, 1, 2, 2, 1, 2, 3, 3, 3, 3, 1, 3, 2, 3, 3, 1, 2,
#        3, 1, 1, 1, 3, 3, 3, 1, 1, 1, 3, 1, 2, 3, 3, 1, 1, 3, 2, 3, 3, 3,
#        3, 2, 3, 3, 1, 3, 1, 3, 1, 3, 3, 3, 1, 2, 3, 3, 3, 3, 3, 3, 3, 2,
#        2, 3, 1, 3, 1, 3, 3, 3, 1, 2, 2, 3, 1, 3, 3, 3, 3, 3, 2, 3, 3, 1,
#        3, 3, 3, 3, 3, 2, 3, 3, 3, 1, 1, 2, 1, 3, 1, 3, 1, 2, 1, 3, 3, 3,
#        3, 3, 1, 3, 1, 3, 3, 3, 2, 3, 2, 3, 1, 3, 1, 3, 3, 3, 3, 3, 3, 2,
#        2, 1, 2, 1, 2, 1, 1, 3, 1, 2, 2, 3, 3, 2, 2, 1, 3, 2, 2, 3, 1, 3,
#        2, 3, 3, 3, 1, 2, 2, 1, 3, 2, 1, 3, 3, 3, 2, 2, 3, 1, 3, 1, 1, 3,
#        2, 3, 2, 3, 1, 3, 3, 3, 3, 2, 2, 1, 3, 3, 1, 3, 1, 3, 2, 1, 1, 2,
#        1, 3, 3, 1, 2, 2, 2, 3, 2, 3, 1, 3, 3, 3, 3, 3, 2, 3, 3, 3, 2, 3,
#        2, 3, 1, 3, 3, 3, 1, 3, 1, 3, 3, 2, 2, 2, 2, 2, 3, 3, 3, 3, 3, 3,
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv("test.csv")

# %%
data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
data.columns = ['passengereId','pclass','name', 'sex', 'Age', 'sibsp', 'parch', 'ticket', 'fare', 'cabin', 'embarked2']

# %%
rawlist = list(data.pclass)

# %%
list(data.name)
# Out:
# ['Kelly, Mr. James',
#  'Wilkes, Mrs. James (Ellen Needs)',
#  'Myles, Mr. Thomas Francis',
#  'Wirz, Mr. Albert',
#  'Hirvonen, Mrs. Alexander (Helga E Lindqvist)',
#  'Svensson, Mr. Johan Cervin',
#  'Connolly, Miss. Kate',
#  'Caldwell, Mr. Albert Francis',
#  'Abrahim, Mrs. Joseph (Sophie Halaut Easu)',
#  'Davies, Mr. John Samuel',
#  'Ilieff, Mr. Ylio',
#  'Jones, Mr. Charles Cresson',
#  'Snyder, Mrs. John Pillsbury (Nelle Stevenson)',
#  'Howard, Mr. Benjamin',
#  'Chaffee, Mrs. Herbert Fuller (Carrie Constance Toogood)',
#  'del Carlo, Mrs. Sebastiano (Argenia Genovesi)',
#  'Keane, Mr. Daniel',
#  'Assaf, Mr. Gerios',
#  'Ilmakangas, Miss. Ida Livija',
#  'Assaf Khalil, Mrs. Mariana (Miriam")"',
#  'Rothschild, Mr. Martin',
#  'Olsen, Master. Artur Karl',
#  'Flegenheim, Mrs. Alfred (Antoinette)',
#  'Williams, Mr. Richard Norris II',
#  'Ryerson, Mrs. Arthur Larned (Emily Maria Borie)',
#  'Robins, Mr. Alexander A',
#  'Ostby, Miss. Helene Ragnhild',
# ...

# %%
test_list = [
    'pclass': list(data.name),
    'sex':'row1',
    'Age':'row1',
    'sibsp':'row1',
    'parch':'row1',
    'ticket':'row1',
    'fare':'row1',
    'cabin':'row1',
    'embarked2':'row1',
]

# %%
test_data = pd.read_csv("test.csv")

# %%
import json

# %%
data_json = json.loads(test_data.to_json(orient='records'))

# %%
train_data = pd.read_csv("train.csv")

# %%
train_data_json = json.loads(train_data.to_json(orient='records'))

# %%
insert_test_col = test_col.insert_many(data_json)
insert_train_col = train_col.insert_many(train_data_json)

# %%
print(myclient.list_database_names())
# Out:
# ['admin', 'config', 'local', 'titanic']

# %%
print(mydb.list_collection_names())
# Out:
# ['test', 'train']

# %%
for doc in train_col.find():
    print(doc)
# Out:
# {'_id': ObjectId('5cb6fedf968e2e2889d624f0'), 'PassengerId': 1, 'Survived': 0, 'Pclass': 3, 'Name': 'Braund, Mr. Owen Harris', 'Sex': 'male', 'Age': 22.0, 'SibSp': 1, 'Parch': 0, 'Ticket': 'A/5 21171', 'Fare': 7.25, 'Cabin': None, 'Embarked': 'S'}
# {'_id': ObjectId('5cb6fedf968e2e2889d624f1'), 'PassengerId': 2, 'Survived': 1, 'Pclass': 1, 'Name': 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)', 'Sex': 'female', 'Age': 38.0, 'SibSp': 1, 'Parch': 0, 'Ticket': 'PC 17599', 'Fare': 71.2833, 'Cabin': 'C85', 'Embarked': 'C'}
# {'_id': ObjectId('5cb6fedf968e2e2889d624f2'), 'PassengerId': 3, 'Survived': 1, 'Pclass': 3, 'Name': 'Heikkinen, Miss. Laina', 'Sex': 'female', 'Age': 26.0, 'SibSp': 0, 'Parch': 0, 'Ticket': 'STON/O2. 3101282', 'Fare': 7.925, 'Cabin': None, 'Embarked': 'S'}
# ...

# %%
for doc in train_col.find({},{'survival':1, 'pclass':1}):
    print(doc)
# Out:
# {'_id': ObjectId('5cb6fedf968e2e2889d624f0')}
# {'_id': ObjectId('5cb6fedf968e2e2889d624f1')}
# {'_id': ObjectId('5cb6fedf968e2e2889d624f2')}
# {'_id': ObjectId('5cb6fedf968e2e2889d624f3')}
# {'_id': ObjectId('5cb6fedf968e2e2889d624f4')}
# {'_id': ObjectId('5cb6fedf968e2e2889d624f5')}
# {'_id': ObjectId('5cb6fedf968e2e2889d624f6')}
# {'_id': ObjectId('5cb6fedf968e2e2889d624f7')}
# {'_id': ObjectId('5cb6fedf968e2e2889d624f8')}
# {'_id': ObjectId('5cb6fedf968e2e2889d624f9')}
# {'_id': ObjectId('5cb6fedf968e2e2889d624fa')}
# {'_id': ObjectId('5cb6fedf968e2e2889d624fb')}
# {'_id': ObjectId('5cb6fedf968e2e2889d624fc')}
# {'_id': ObjectId('5cb6fedf968e2e2889d624fd')}
# {'_id': ObjectId('5cb6fedf968e2e2889d624fe')}
# {'_id': ObjectId('5cb6fedf968e2e2889d624ff')}
# {'_id': ObjectId('5cb6fedf968e2e2889d62500')}
# {'_id': ObjectId('5cb6fedf968e2e2889d62501')}
# {'_id': ObjectId('5cb6fedf968e2e2889d62502')}
# {'_id': ObjectId('5cb6fedf968e2e2889d62503')}
# ...

# %%
query = { "Age": { "$gt": 20 } }

docs_test = test_col.find(query)
docs_train = train_col.find(query)

for doc in docs_test:
    print(doc)
    
for doc in docs_train:
    print(doc)
# Out:
# {'_id': ObjectId('5cb6fedf968e2e2889d6234e'), 'PassengerId': 892, 'Pclass': 3, 'Name': 'Kelly, Mr. James', 'Sex': 'male', 'Age': 34.5, 'SibSp': 0, 'Parch': 0, 'Ticket': '330911', 'Fare': 7.8292, 'Cabin': None, 'Embarked': 'Q'}
# {'_id': ObjectId('5cb6fedf968e2e2889d6234f'), 'PassengerId': 893, 'Pclass': 3, 'Name': 'Wilkes, Mrs. James (Ellen Needs)', 'Sex': 'female', 'Age': 47.0, 'SibSp': 1, 'Parch': 0, 'Ticket': '363272', 'Fare': 7.0, 'Cabin': None, 'Embarked': 'S'}
# {'_id': ObjectId('5cb6fedf968e2e2889d62350'), 'PassengerId': 894, 'Pclass': 2, 'Name': 'Myles, Mr. Thomas Francis', 'Sex': 'male', 'Age': 62.0, 'SibSp': 0, 'Parch': 0, 'Ticket': '240276', 'Fare': 9.6875, 'Cabin': None, 'Embarked': 'Q'}
# {'_id': ObjectId('5cb6fedf968e2e2889d62351'), 'PassengerId': 895, 'Pclass': 3, 'Name': 'Wirz, Mr. Albert', 'Sex': 'male', 'Age': 27.0, 'SibSp': 0, 'Parch': 0, 'Ticket': '315154', 'Fare': 8.6625, 'Cabin': None, 'Embarked': 'S'}
# ...

# %%
for doc in train_col.find():
    print(doc)
# Out:
# {'_id': ObjectId('5cb6fedf968e2e2889d624f0'), 'PassengerId': 1, 'Survived': 0, 'Pclass': 3, 'Name': 'Braund, Mr. Owen Harris', 'Sex': 'male', 'Age': 22.0, 'SibSp': 1, 'Parch': 0, 'Ticket': 'A/5 21171', 'Fare': 7.25, 'Cabin': None, 'Embarked': 'S'}
# {'_id': ObjectId('5cb6fedf968e2e2889d624f1'), 'PassengerId': 2, 'Survived': 1, 'Pclass': 1, 'Name': 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)', 'Sex': 'female', 'Age': 38.0, 'SibSp': 1, 'Parch': 0, 'Ticket': 'PC 17599', 'Fare': 71.2833, 'Cabin': 'C85', 'Embarked': 'C'}
# {'_id': ObjectId('5cb6fedf968e2e2889d624f2'), 'PassengerId': 3, 'Survived': 1, 'Pclass': 3, 'Name': 'Heikkinen, Miss. Laina', 'Sex': 'female', 'Age': 26.0, 'SibSp': 0, 'Parch': 0, 'Ticket': 'STON/O2. 3101282', 'Fare': 7.925, 'Cabin': None, 'Embarked': 'S'}
# ...

# %%
myclient.drop_database("titanic")

# %%
print(myclient.list_database_names())
# Out:
# ['admin', 'config', 'local']
